# %% [markdown]
# **Task 1 : Importing Necessary Libraries**

# %%
import pandas as pd    #Data analysis and Manipulation
import matplotlib.pyplot as plt  #Data Visulization

# %% [markdown]
# **Importing Plotly**

# %%
#Import Plotly
import plotly.offline as py
py.init_notebook_mode(connected=True) #Show plot on notebook when lernal is running
import plotly.graph_objs as go      
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Initialize Plotly
import plotly.io as pio
pio.renderers.default= 'colab'

# %% [markdown]
# **Task 2 : Importing the Dataset 1**

# %%
#Import Dataset1
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-259eedf7-ecef-423a-9a3d-859eba77100e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-259eedf7-ecef-423a-9a3d-859eba77100e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving covid.csv to covid (2).csv
# ...

# %%
df1=pd.read_csv("covid.csv")
print(df1.shape)
df1.head()
# Out:
# (209, 17)
#   Country/Region      Continent  ...      WHO Region  iso_alpha
# 0            USA  North America  ...        Americas        USA
# 1         Brazil  South America  ...        Americas        BRA
# 2          India           Asia  ...  South-EastAsia        IND
# 3         Russia         Europe  ...          Europe        RUS
# 4   South Africa         Africa  ...          Africa        ZAF
#
# [5 rows x 17 columns]

# %%
df1.tail()
# Out:
#             Country/Region      Continent  ...  WHO Region  iso_alpha
# 204             Montserrat  North America  ...         NaN        MSR
# 205  Caribbean Netherlands  North America  ...         NaN
# 206       Falkland Islands  South America  ...         NaN        FLK
# 207           Vatican City         Europe  ...      Europe        VAT
# 208         Western Sahara         Africa  ...      Africa        ESH
#
# [5 rows x 17 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country/Region    209 non-null    object
#  1   Continent         208 non-null    object
#  2   Population        208 non-null    float64
#  3   TotalCases        209 non-null    int64
#  4   NewCases          4 non-null      float64
#  5   TotalDeaths       188 non-null    float64
#  6   NewDeaths         3 non-null      float64
#  7   TotalRecovered    205 non-null    float64
#  8   NewRecovered      3 non-null      float64
#  9   ActiveCases       205 non-null    float64
#  10  Serious,Critical  122 non-null    float64
#  11  Tot Cases/1M pop  208 non-null    float64
#  12  Deaths/1M pop     187 non-null    float64
#  13  TotalTests        191 non-null    float64
#  14  Tests/1M pop      191 non-null    float64
#  15  WHO Region        184 non-null    object
# ...

# %%
df1.isnull().sum()
# Out:
# Country/Region        0
# Continent             1
# Population            1
# TotalCases            0
# NewCases            205
# TotalDeaths          21
# NewDeaths           206
# TotalRecovered        4
# NewRecovered        206
# ActiveCases           4
# Serious,Critical     87
# Tot Cases/1M pop      1
# Deaths/1M pop        22
# TotalTests           18
# Tests/1M pop         18
# WHO Region           25
# iso_alpha             0
# dtype: int64

# %%
#Drop column 
df1.drop(['NewCases', 'NewDeaths','NewRecovered'], axis=1, inplace=True)

# %%
print(df1.shape)
# Out:
# (209, 14)

# %%
from plotly.figure_factory import create_table
table= create_table(df1.head(10), colorscale='blues')
py.iplot(table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b4096cc9-13fa-495b-ab2b-efac947ff2f9" class="plotly-graph-div" style="height:380px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b4096cc9-13fa-495b-ab2b-efac947ff2f9")) {
#                     Plotly.newPlot(
#                         'b4096cc9-13fa-495b-ab2b-efac947ff2f9',
# ...

# %% [markdown]
# **Task 3 : Visualization with Custom Bar Charts**

# %%
# Bar plot dataset,x,y,color,orientation(if you want),height,hover_data,title(if you want)
df1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop',
#        'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
px.bar(df1.head(25), x="Country/Region", y="TotalCases", color="Country/Region", height=500, hover_data=['Country/Region','Continent'],title="Bar Plot of Country/Region vs TotalCases ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7b880601-d7f8-45ad-8f07-d9cf951c2f3b" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7b880601-d7f8-45ad-8f07-d9cf951c2f3b")) {
#                     Plotly.newPlot(
#                         '7b880601-d7f8-45ad-8f07-d9cf951c2f3b',
# ...

# %%
px.bar(df1.head(25), x="Country/Region", y="TotalDeaths", color="Country/Region", height=500, hover_data=['Country/Region','Continent'],title="Bar Plot of Country/Region vs TotalDeaths ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3e39cda6-035e-4630-899a-43fc6f4a9d40" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3e39cda6-035e-4630-899a-43fc6f4a9d40")) {
#                     Plotly.newPlot(
#                         '3e39cda6-035e-4630-899a-43fc6f4a9d40',
# ...

# %%
px.bar(df1.head(25), x="Country/Region", y="TotalRecovered", color="Country/Region", height=500, hover_data=['Country/Region','Continent'],title="Bar Plot of Country/Region vs TotalRecovered ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a6acc1ec-aacb-447a-a8a1-f23d8f6e7002" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a6acc1ec-aacb-447a-a8a1-f23d8f6e7002")) {
#                     Plotly.newPlot(
#                         'a6acc1ec-aacb-447a-a8a1-f23d8f6e7002',
# ...

# %%
px.bar(df1.head(25), x="TotalTests", y="Country/Region", color="TotalTests", height=500,orientation="h", hover_data=['Country/Region','Continent'],title="Bar Plot of Country/Region vs TotalTests ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16ad5ef7-f412-4def-957b-11352892845d" class="plotly-graph-div" style="height:500px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16ad5ef7-f412-4def-957b-11352892845d")) {
#                     Plotly.newPlot(
#                         '16ad5ef7-f412-4def-957b-11352892845d',
# ...

# %% [markdown]
# **Task 4 : Data Visualization using Bubble Chart**

# %%
# px.scatter,  x,y,size,color,hover_data,size_max,log_x,log_y
df1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop',
#        'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
px.scatter(df1.head(50), x="Continent", y="TotalCases", color="TotalCases", size="TotalCases",size_max=50, hover_data=['Country/Region','Continent'],title="Bubble chart of Continent vs TotalCases ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cac8029f-32ca-451d-93c1-6fa162c75250" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cac8029f-32ca-451d-93c1-6fa162c75250")) {
#                     Plotly.newPlot(
#                         'cac8029f-32ca-451d-93c1-6fa162c75250',
# ...

# %%
  # Previous some plot are not clearly visiable so we put log_y="True"
  px.scatter(df1.head(50), x="Continent", y="TotalCases", color="TotalCases", size="TotalCases",size_max=50, hover_data=['Country/Region','Continent'],log_y="True",title="Bubble chart of Continent vs TotalCases ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e95b5669-b185-4875-862d-46b8e15fcaca" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e95b5669-b185-4875-862d-46b8e15fcaca")) {
#                     Plotly.newPlot(
#                         'e95b5669-b185-4875-862d-46b8e15fcaca',
# ...

# %%
px.scatter(df1.head(50), x="Continent", y="TotalCases", color="TotalTests", size="TotalCases",size_max=80, hover_data=['Country/Region','Continent'],log_y="True",title="Bubble chart of Continent vs TotalTests ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="311006b7-b25b-42cd-837c-426a1827f517" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("311006b7-b25b-42cd-837c-426a1827f517")) {
#                     Plotly.newPlot(
#                         '311006b7-b25b-42cd-837c-426a1827f517',
# ...

# %%
px.scatter(df1.head(50), x="Country/Region", y="TotalCases", color="Country/Region", size="TotalCases",size_max=80, hover_data=['Country/Region','Continent'],log_y="True",title="Bubble chart of Country/Region vs TotalCases ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7984fd53-f3d0-42c6-953c-9b031261d48b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7984fd53-f3d0-42c6-953c-9b031261d48b")) {
#                     Plotly.newPlot(
#                         '7984fd53-f3d0-42c6-953c-9b031261d48b',
# ...

# %%
px.scatter(df1.head(50), x="Country/Region", y="TotalDeaths", color="Country/Region", size="TotalCases",size_max=100, hover_data=['Country/Region','Continent'],log_y="True",title="Bubble chart of Country/Region vs TotalDeaths ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e465eca1-286c-4253-b07a-5aa3f86e6ff0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e465eca1-286c-4253-b07a-5aa3f86e6ff0")) {
#                     Plotly.newPlot(
#                         'e465eca1-286c-4253-b07a-5aa3f86e6ff0',
# ...

# %%
px.scatter(df1.head(30), x="Country/Region", y="Tot Cases/1M pop", color="Tot Cases/1M pop", size="Tot Cases/1M pop",size_max=100, hover_data=['Country/Region','Continent'],log_y="True",title="Bubble chart of Country/Region vs Tot Cases/1M pop ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="78d33fb0-2d32-4104-b950-101b8bb28a9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("78d33fb0-2d32-4104-b950-101b8bb28a9a")) {
#                     Plotly.newPlot(
#                         '78d33fb0-2d32-4104-b950-101b8bb28a9a',
# ...

# %%
df1.columns
# Out:
# Index(['Country/Region', 'Continent', 'Population', 'TotalCases',
#        'TotalDeaths', 'TotalRecovered', 'ActiveCases', 'Serious,Critical',
#        'Tot Cases/1M pop', 'Deaths/1M pop', 'TotalTests', 'Tests/1M pop',
#        'WHO Region', 'iso_alpha'],
#       dtype='object')

# %%
px.scatter(df1.head(30), x="TotalCases", y="TotalDeaths", color="TotalDeaths", size="TotalDeaths",size_max=100, hover_data=['Country/Region','Continent'],log_x="True",log_y="True",title="Bubble chart of TotalCases vs TotalDeaths ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e7201f85-f6d5-4452-8072-653f964410c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7201f85-f6d5-4452-8072-653f964410c4")) {
#                     Plotly.newPlot(
#                         'e7201f85-f6d5-4452-8072-653f964410c4',
# ...

# %%
px.scatter(df1.head(30), x="TotalCases", y="TotalTests", color="TotalTests", size="TotalDeaths",size_max=100, hover_data=['Country/Region','Continent'],title="Bubble chart of TotalCases vs TotalTests ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ead93a23-4e6f-4b1e-9cf4-3e4bb1753af1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ead93a23-4e6f-4b1e-9cf4-3e4bb1753af1")) {
#                     Plotly.newPlot(
#                         'ead93a23-4e6f-4b1e-9cf4-3e4bb1753af1',
# ...
